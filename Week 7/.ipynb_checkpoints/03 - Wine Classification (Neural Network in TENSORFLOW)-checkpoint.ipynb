# %% [markdown]
# ## Neural Network using Tensorflow
#
# This exercise is adapted from https://www.springboard.com/blog/beginners-guide-neural-network-in-python-scikit-learn-0-18/

# %% [markdown]
# Now you have successfully used SciKit Learn's MLP to work on the built-in Breast Cancer Data Set, let's try another one!
#
# Download the wine dataset from UCI Machine learning repository (http://archive.ics.uci.edu/ml/datasets/Wine/). Import the dataset into a pandas dataframe

# %% [markdown]
# ## Setup

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from tensorflow import keras
from tensorflow.keras import layers

# %% [markdown]
# ## Preparing the data
#
# Let's download the data and load it into a Pandas dataframe:

# %%
import pandas as pd
dataframe = pd.read_csv('./Data/Wine.csv')

# %% [markdown]
# Check out the dataframe - what are the first few rows of data?

# %%
# find out the attributes in the dataset
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Alcohol               178 non-null    float64
#  1   Malic_Acid            178 non-null    float64
#  2   Ash                   178 non-null    float64
#  3   Ash_Alcanity          178 non-null    float64
#  4   Magnesium             178 non-null    int64
#  5   Total_Phenols         178 non-null    float64
#  6   Flavanoids            178 non-null    float64
#  7   Nonflavanoid_Phenols  178 non-null    float64
#  8   Proanthocyanins       178 non-null    float64
#  9   Color_Intensity       178 non-null    float64
#  10  Hue                   178 non-null    float64
#  11  OD280                 178 non-null    float64
#  12  Proline               178 non-null    int64
#  13  Customer_Segment      178 non-null    int64
# dtypes: float64(11), int64(3)
# memory usage: 19.6 KB

# %%
# find out the total instances and number of features
dataframe.shape
# Out:
# (178, 14)

# %%
# use describe to find out more about the data
dataframe.describe().transpose()
# Out:
#                       count        mean         std     min       25%  \
# Alcohol               178.0   13.000618    0.811827   11.03   12.3625
# Malic_Acid            178.0    2.336348    1.117146    0.74    1.6025
# Ash                   178.0    2.366517    0.274344    1.36    2.2100
# Ash_Alcanity          178.0   19.494944    3.339564   10.60   17.2000
# Magnesium             178.0   99.741573   14.282484   70.00   88.0000
# Total_Phenols         178.0    2.295112    0.625851    0.98    1.7425
# Flavanoids            178.0    2.029270    0.998859    0.34    1.2050
# Nonflavanoid_Phenols  178.0    0.361854    0.124453    0.13    0.2700
# Proanthocyanins       178.0    1.590899    0.572359    0.41    1.2500
# Color_Intensity       178.0    5.058090    2.318286    1.28    3.2200
# Hue                   178.0    0.957449    0.228572    0.48    0.7825
# OD280                 178.0    2.611685    0.709990    1.27    1.9375
# Proline               178.0  746.893258  314.907474  278.00  500.5000
# Customer_Segment      178.0    1.938202    0.775035    1.00    1.0000
#
#                           50%       75%      max
# Alcohol                13.050   13.6775    14.83
# Malic_Acid              1.865    3.0825     5.80
# Ash                     2.360    2.5575     3.23
# Ash_Alcanity           19.500   21.5000    30.00
# Magnesium              98.000  107.0000   162.00
# Total_Phenols           2.355    2.8000     3.88
# Flavanoids              2.135    2.8750     5.08
# Nonflavanoid_Phenols    0.340    0.4375     0.66
# Proanthocyanins         1.555    1.9500     3.58
# Color_Intensity         4.690    6.2000    13.00
# Hue                     0.965    1.1200     1.71
# OD280                   2.780    3.1700     4.00
# Proline               673.500  985.0000  1680.00
# Customer_Segment        2.000    3.0000     3.00

# %%
dataframe.head()
# Out:
#    Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0    14.23        1.71  2.43          15.6        127           2.80
# 1    13.20        1.78  2.14          11.2        100           2.65
# 2    13.16        2.36  2.67          18.6        101           2.80
# 3    14.37        1.95  2.50          16.8        113           3.85
# 4    13.24        2.59  2.87          21.0        118           2.80
#
#    Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    OD280  Proline  Customer_Segment
# 0   3.92     1065                 1
# 1   3.40     1050                 1
# 2   3.17     1185                 1
# 3   3.45     1480                 1
# 4   2.93      735                 1

# %% [markdown]
# Let's split the data into a training and validation set:

# %%
val_dataframe = dataframe.sample(frac=0.2, random_state=4321)
train_dataframe = dataframe.drop(val_dataframe.index)

print(
    "Using %d samples for training and %d for validation"
    % (len(train_dataframe), len(val_dataframe))
)
# Out:
# Using 142 samples for training and 36 for validation

# %% [markdown]
# Let's generate `tf.data.Dataset` objects for each dataframe:

# %%
def dataframe_to_dataset(dataframe):
    dataframe = dataframe.copy()
    labels = dataframe.pop("Customer_Segment")
    ds = tf.data.Dataset.from_tensor_slices((dict(dataframe), labels))
    ds = ds.shuffle(buffer_size=len(dataframe))
    return ds


train_ds = dataframe_to_dataset(train_dataframe)
val_ds = dataframe_to_dataset(val_dataframe)

# %% [markdown]
# Each `Dataset` yields a tuple `(input, target)` where `input` is a dictionary of features
# and `target` is the value `0` or `1`:

# %%
for x, y in train_ds.take(1):
    print("Input:", x)
    print("Target:", y)
# Out:
# Input: {'Alcohol': <tf.Tensor: shape=(), dtype=float64, numpy=13.49>, 'Malic_Acid': <tf.Tensor: shape=(), dtype=float64, numpy=3.59>, 'Ash': <tf.Tensor: shape=(), dtype=float64, numpy=2.19>, 'Ash_Alcanity': <tf.Tensor: shape=(), dtype=float64, numpy=19.5>, 'Magnesium': <tf.Tensor: shape=(), dtype=int64, numpy=88>, 'Total_Phenols': <tf.Tensor: shape=(), dtype=float64, numpy=1.62>, 'Flavanoids': <tf.Tensor: shape=(), dtype=float64, numpy=0.48>, 'Nonflavanoid_Phenols': <tf.Tensor: shape=(), dtype=float64, numpy=0.58>, 'Proanthocyanins': <tf.Tensor: shape=(), dtype=float64, numpy=0.88>, 'Color_Intensity': <tf.Tensor: shape=(), dtype=float64, numpy=5.7>, 'Hue': <tf.Tensor: shape=(), dtype=float64, numpy=0.81>, 'OD280': <tf.Tensor: shape=(), dtype=float64, numpy=1.82>, 'Proline': <tf.Tensor: shape=(), dtype=int64, numpy=580>}
# Target: tf.Tensor(3, shape=(), dtype=int64)

# %% [markdown]
# Let's batch the datasets:

# %%
train_ds = train_ds.batch(18)
val_ds = val_ds.batch(18)

# %% [markdown]
# ## Feature preprocessing with Keras layers

# %%
from tensorflow.keras.layers import IntegerLookup
from tensorflow.keras.layers import Normalization
from tensorflow.keras.layers import StringLookup


def encode_numerical_feature(feature, name, dataset):
    # Create a Normalization layer for our feature
    normalizer = Normalization()

    # Prepare a Dataset that only yields our feature
    feature_ds = dataset.map(lambda x, y: x[name])
    feature_ds = feature_ds.map(lambda x: tf.expand_dims(x, -1))

    # Learn the statistics of the data
    normalizer.adapt(feature_ds)

    # Normalize the input feature
    encoded_feature = normalizer(feature)
    return encoded_feature


def encode_categorical_feature(feature, name, dataset, is_string):
    lookup_class = StringLookup if is_string else IntegerLookup
    # Create a lookup layer which will turn strings into integer indices
    lookup = lookup_class(output_mode="binary")

    # Prepare a Dataset that only yields our feature
    feature_ds = dataset.map(lambda x, y: x[name])
    feature_ds = feature_ds.map(lambda x: tf.expand_dims(x, -1))

    # Learn the set of possible string values and assign them a fixed integer index
    lookup.adapt(feature_ds)

    # Turn the string input into integer indices
    encoded_feature = lookup(feature)
    return encoded_feature

# %% [markdown]
# ## Build a model
#
# With this done, we can create our end-to-end model:

# %%
dataframe.describe().transpose()
# Out:
#                       count        mean         std     min       25%  \
# Alcohol               178.0   13.000618    0.811827   11.03   12.3625
# Malic_Acid            178.0    2.336348    1.117146    0.74    1.6025
# Ash                   178.0    2.366517    0.274344    1.36    2.2100
# Ash_Alcanity          178.0   19.494944    3.339564   10.60   17.2000
# Magnesium             178.0   99.741573   14.282484   70.00   88.0000
# Total_Phenols         178.0    2.295112    0.625851    0.98    1.7425
# Flavanoids            178.0    2.029270    0.998859    0.34    1.2050
# Nonflavanoid_Phenols  178.0    0.361854    0.124453    0.13    0.2700
# Proanthocyanins       178.0    1.590899    0.572359    0.41    1.2500
# Color_Intensity       178.0    5.058090    2.318286    1.28    3.2200
# Hue                   178.0    0.957449    0.228572    0.48    0.7825
# OD280                 178.0    2.611685    0.709990    1.27    1.9375
# Proline               178.0  746.893258  314.907474  278.00  500.5000
# Customer_Segment      178.0    1.938202    0.775035    1.00    1.0000
#
#                           50%       75%      max
# Alcohol                13.050   13.6775    14.83
# Malic_Acid              1.865    3.0825     5.80
# Ash                     2.360    2.5575     3.23
# Ash_Alcanity           19.500   21.5000    30.00
# Magnesium              98.000  107.0000   162.00
# Total_Phenols           2.355    2.8000     3.88
# Flavanoids              2.135    2.8750     5.08
# Nonflavanoid_Phenols    0.340    0.4375     0.66
# Proanthocyanins         1.555    1.9500     3.58
# Color_Intensity         4.690    6.2000    13.00
# Hue                     0.965    1.1200     1.71
# OD280                   2.780    3.1700     4.00
# Proline               673.500  985.0000  1680.00
# Customer_Segment        2.000    3.0000     3.00

# %%
# Numerical features
Alcohol = keras.Input(shape=(1,), name="Alcohol")
Malic_Acid = keras.Input(shape=(1,), name="Malic_Acid")
Ash = keras.Input(shape=(1,), name="Ash")
Ash_Alcanity = keras.Input(shape=(1,), name="Ash_Alcanity")
Magnesium = keras.Input(shape=(1,), name="Magnesium")
Total_Phenols = keras.Input(shape=(1,), name="Total_Phenols")
Flavanoids = keras.Input(shape=(1,), name="Flavanoids")
Nonflavanoid_Phenols = keras.Input(shape=(1,), name="Nonflavanoid_Phenols")
Proanthocyanins = keras.Input(shape=(1,), name="Proanthocyanins")
Color_Intensity = keras.Input(shape=(1,), name="Color_Intensity")
Hue = keras.Input(shape=(1,), name="Hue")
OD280 = keras.Input(shape=(1,), name="OD280")
Proline = keras.Input(shape=(1,), name="Proline")

all_inputs = [
    Alcohol,
    Malic_Acid,
    Ash,
    Ash_Alcanity,
    Magnesium,
    Total_Phenols,
    Flavanoids,
    Nonflavanoid_Phenols,
    Proanthocyanins,
    Color_Intensity,
    Hue,
    OD280,
    Proline,
]

# Numerical features
Alcohol_encoded = encode_numerical_feature(Alcohol, "Alcohol", train_ds)
Malic_Acid_encoded = encode_numerical_feature(Malic_Acid, "Malic_Acid", train_ds)
Ash_encoded = encode_numerical_feature(Ash, "Ash", train_ds)
Ash_Alcanity_encoded = encode_numerical_feature(Ash_Alcanity, "Ash_Alcanity", train_ds)
Magnesium_encoded = encode_numerical_feature(Magnesium, "Magnesium", train_ds)
Total_Phenols_encoded = encode_numerical_feature(Total_Phenols, "Total_Phenols", train_ds)
Flavanoids_encoded = encode_numerical_feature(Flavanoids, "Flavanoids", train_ds)
Nonflavanoid_Phenols_encoded = encode_numerical_feature(Nonflavanoid_Phenols, "Nonflavanoid_Phenols", train_ds)
Proanthocyanins_encoded = encode_numerical_feature(Proanthocyanins, "Proanthocyanins", train_ds)
Color_Intensity_encoded = encode_numerical_feature(Color_Intensity, "Color_Intensity", train_ds)
Hue_encoded = encode_numerical_feature(Hue, "Hue", train_ds)
OD280_encoded = encode_numerical_feature(OD280, "OD280", train_ds)
Proline_encoded = encode_numerical_feature(Proline, "Proline", train_ds)

all_features = layers.concatenate(
    [
        Alcohol_encoded,
        Malic_Acid_encoded,
        Ash_encoded,
        Ash_Alcanity_encoded,
        Magnesium_encoded,
        Total_Phenols_encoded,
        Flavanoids_encoded,
        Nonflavanoid_Phenols_encoded,
        Proanthocyanins_encoded,
        Color_Intensity_encoded,
        Hue_encoded,
        OD280_encoded,
        Proline_encoded,
    ]
)
x = layers.Dense(18, activation="relu")(all_features)
x = layers.Dropout(0.5)(x)
output = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(all_inputs, output)
model.compile("adam", "binary_crossentropy", metrics=["accuracy"])

# %%
# `rankdir='LR'` is to make the graph horizontal.
keras.utils.plot_model(model, show_shapes=True, rankdir="LR")
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.

# %% [markdown]
# ### Training the model

# %%
model.fit(train_ds, epochs=50, validation_data=val_ds)
# Out:
# Epoch 1/50
# 8/8 [==============================] - 2s 68ms/step - loss: -0.4283 - accuracy: 0.1690 - val_loss: -0.3173 - val_accuracy: 0.2222
# Epoch 2/50
# 8/8 [==============================] - 0s 10ms/step - loss: -0.5332 - accuracy: 0.2113 - val_loss: -0.4582 - val_accuracy: 0.2500
# Epoch 3/50
# 8/8 [==============================] - 0s 9ms/step - loss: -0.6244 - accuracy: 0.1620 - val_loss: -0.5939 - val_accuracy: 0.2500
# Epoch 4/50
# 8/8 [==============================] - 0s 11ms/step - loss: -0.8309 - accuracy: 0.2042 - val_loss: -0.7270 - val_accuracy: 0.2500
# Epoch 5/50
# 8/8 [==============================] - 0s 9ms/step - loss: -0.7863 - accuracy: 0.1690 - val_loss: -0.8594 - val_accuracy: 0.2500
# Epoch 6/50
# 8/8 [==============================] - 0s 9ms/step - loss: -1.1267 - accuracy: 0.2113 - val_loss: -0.9949 - val_accuracy: 0.2778
# Epoch 7/50
# 8/8 [==============================] - 0s 10ms/step - loss: -1.5264 - accuracy: 0.1972 - val_loss: -1.1390 - val_accuracy: 0.2778
# Epoch 8/50
# 8/8 [==============================] - 0s 9ms/step - loss: -1.7111 - accuracy: 0.2042 - val_loss: -1.2861 - val_accuracy: 0.3056
# Epoch 9/50
# 8/8 [==============================] - 0s 9ms/step - loss: -1.6027 - accuracy: 0.2183 - val_loss: -1.4322 - val_accuracy: 0.3056
# Epoch 10/50
# 8/8 [==============================] - 0s 10ms/step - loss: -1.9327 - accuracy: 0.2254 - val_loss: -1.5785 - val_accuracy: 0.3333
# Epoch 11/50
# 8/8 [==============================] - 0s 9ms/step - loss: -2.0117 - accuracy: 0.2254 - val_loss: -1.7264 - val_accuracy: 0.3333
# Epoch 12/50
# 8/8 [==============================] - 0s 10ms/step - loss: -2.2276 - accuracy: 0.2254 - val_loss: -1.8794 - val_accuracy: 0.3333
# Epoch 13/50
# 8/8 [==============================] - 0s 10ms/step - loss: -2.5388 - accuracy: 0.2676 - val_loss: -2.0375 - val_accuracy: 0.3333
# Epoch 14/50
# 8/8 [==============================] - 0s 11ms/step - loss: -2.4778 - accuracy: 0.2394 - val_loss: -2.1985 - val_accuracy: 0.3333
# Epoch 15/50
# 8/8 [==============================] - 0s 9ms/step - loss: -2.8737 - accuracy: 0.2042 - val_loss: -2.3657 - val_accuracy: 0.3333
# Epoch 16/50
# 8/8 [==============================] - 0s 10ms/step - loss: -3.2397 - accuracy: 0.2535 - val_loss: -2.5386 - val_accuracy: 0.3333
# Epoch 17/50
# 8/8 [==============================] - 0s 9ms/step - loss: -3.3521 - accuracy: 0.2254 - val_loss: -2.7219 - val_accuracy: 0.3611
# Epoch 18/50
# 8/8 [==============================] - 0s 10ms/step - loss: -3.7914 - accuracy: 0.2535 - val_loss: -2.9053 - val_accuracy: 0.3611
# Epoch 19/50
# 8/8 [==============================] - 0s 10ms/step - loss: -3.6265 - accuracy: 0.2887 - val_loss: -3.0910 - val_accuracy: 0.3611
# Epoch 20/50
# 8/8 [==============================] - 0s 9ms/step - loss: -3.9115 - accuracy: 0.2465 - val_loss: -3.2804 - val_accuracy: 0.3889
# Epoch 21/50
# 8/8 [==============================] - 0s 8ms/step - loss: -4.1661 - accuracy: 0.2746 - val_loss: -3.4755 - val_accuracy: 0.3889
# Epoch 22/50
# 8/8 [==============================] - 0s 8ms/step - loss: -5.0153 - accuracy: 0.2676 - val_loss: -3.6794 - val_accuracy: 0.3889
# Epoch 23/50
# 8/8 [==============================] - 0s 9ms/step - loss: -5.5700 - accuracy: 0.2958 - val_loss: -3.9013 - val_accuracy: 0.3889
# Epoch 24/50
# 8/8 [==============================] - 0s 9ms/step - loss: -6.2414 - accuracy: 0.2958 - val_loss: -4.1413 - val_accuracy: 0.3889
# Epoch 25/50
# 8/8 [==============================] - 0s 10ms/step - loss: -6.1067 - accuracy: 0.2817 - val_loss: -4.3934 - val_accuracy: 0.3889
# Epoch 26/50
# 8/8 [==============================] - 0s 11ms/step - loss: -6.3961 - accuracy: 0.2887 - val_loss: -4.6517 - val_accuracy: 0.3889
# Epoch 27/50
# 8/8 [==============================] - 0s 9ms/step - loss: -6.5817 - accuracy: 0.2535 - val_loss: -4.9179 - val_accuracy: 0.3889
# Epoch 28/50
# 8/8 [==============================] - 0s 9ms/step - loss: -6.4216 - accuracy: 0.2887 - val_loss: -5.1822 - val_accuracy: 0.3889
# Epoch 29/50
# 8/8 [==============================] - 0s 11ms/step - loss: -7.0809 - accuracy: 0.2958 - val_loss: -5.4486 - val_accuracy: 0.3889
# Epoch 30/50
# 8/8 [==============================] - 0s 9ms/step - loss: -7.6485 - accuracy: 0.2817 - val_loss: -5.7339 - val_accuracy: 0.3889
# Epoch 31/50
# 8/8 [==============================] - 0s 9ms/step - loss: -8.0387 - accuracy: 0.2535 - val_loss: -6.0326 - val_accuracy: 0.3889
# Epoch 32/50
# 8/8 [==============================] - 0s 9ms/step - loss: -9.0685 - accuracy: 0.2746 - val_loss: -6.3500 - val_accuracy: 0.3889
# Epoch 33/50
# 8/8 [==============================] - 0s 9ms/step - loss: -9.4489 - accuracy: 0.2746 - val_loss: -6.6667 - val_accuracy: 0.3889
# Epoch 34/50
# 8/8 [==============================] - 0s 9ms/step - loss: -9.3581 - accuracy: 0.2887 - val_loss: -7.0006 - val_accuracy: 0.3889
# Epoch 35/50
# 8/8 [==============================] - 0s 9ms/step - loss: -11.0946 - accuracy: 0.2958 - val_loss: -7.3534 - val_accuracy: 0.3889
# Epoch 36/50
# 8/8 [==============================] - 0s 9ms/step - loss: -10.2881 - accuracy: 0.2746 - val_loss: -7.7070 - val_accuracy: 0.3889
# Epoch 37/50
# 8/8 [==============================] - 0s 9ms/step - loss: -10.9891 - accuracy: 0.2958 - val_loss: -8.0687 - val_accuracy: 0.3889
# Epoch 38/50
# 8/8 [==============================] - 0s 8ms/step - loss: -11.6744 - accuracy: 0.2958 - val_loss: -8.4521 - val_accuracy: 0.3889
# Epoch 39/50
# 8/8 [==============================] - 0s 9ms/step - loss: -12.5715 - accuracy: 0.2887 - val_loss: -8.8338 - val_accuracy: 0.3889
# Epoch 40/50
# 8/8 [==============================] - 0s 8ms/step - loss: -12.2759 - accuracy: 0.3169 - val_loss: -9.2141 - val_accuracy: 0.3889
# Epoch 41/50
# 8/8 [==============================] - 0s 8ms/step - loss: -14.0449 - accuracy: 0.2958 - val_loss: -9.6297 - val_accuracy: 0.3889
# Epoch 42/50
# 8/8 [==============================] - 0s 9ms/step - loss: -15.2604 - accuracy: 0.2887 - val_loss: -10.0757 - val_accuracy: 0.3889
# Epoch 43/50
# 8/8 [==============================] - 0s 9ms/step - loss: -14.5951 - accuracy: 0.2887 - val_loss: -10.5342 - val_accuracy: 0.3889
# Epoch 44/50
# 8/8 [==============================] - 0s 9ms/step - loss: -14.5144 - accuracy: 0.2817 - val_loss: -10.9702 - val_accuracy: 0.3889
# Epoch 45/50
# 8/8 [==============================] - 0s 8ms/step - loss: -15.0835 - accuracy: 0.2958 - val_loss: -11.4124 - val_accuracy: 0.3889
# Epoch 46/50
# 8/8 [==============================] - 0s 8ms/step - loss: -17.8957 - accuracy: 0.3028 - val_loss: -11.8842 - val_accuracy: 0.3889
# Epoch 47/50
# 8/8 [==============================] - 0s 8ms/step - loss: -16.3301 - accuracy: 0.2887 - val_loss: -12.3827 - val_accuracy: 0.3889
# Epoch 48/50
# 8/8 [==============================] - 0s 9ms/step - loss: -17.7133 - accuracy: 0.2746 - val_loss: -12.8644 - val_accuracy: 0.3889
# Epoch 49/50
# 8/8 [==============================] - 0s 9ms/step - loss: -17.9865 - accuracy: 0.2887 - val_loss: -13.3847 - val_accuracy: 0.3889
# Epoch 50/50
# 8/8 [==============================] - 0s 8ms/step - loss: -19.8163 - accuracy: 0.3028 - val_loss: -13.9107 - val_accuracy: 0.3889
